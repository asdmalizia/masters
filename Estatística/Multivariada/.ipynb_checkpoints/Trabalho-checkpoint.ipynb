# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA, SparsePCA

# %%
# !pip install kagglehub[pandas-datasets]
# Out:
# Collecting kagglehub[pandas-datasets]
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\aless\desktop\codes\venv\lib\site-packages (from kagglehub[pandas-datasets]) (25.0)
# Requirement already satisfied: pyyaml in c:\users\aless\desktop\codes\venv\lib\site-packages (from kagglehub[pandas-datasets]) (6.0.1)
# Requirement already satisfied: requests in c:\users\aless\desktop\codes\venv\lib\site-packages (from kagglehub[pandas-datasets]) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\aless\desktop\codes\venv\lib\site-packages (from kagglehub[pandas-datasets]) (4.67.1)
# Requirement already satisfied: pandas in c:\users\aless\desktop\codes\venv\lib\site-packages (from kagglehub[pandas-datasets]) (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\aless\desktop\codes\venv\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aless\desktop\codes\venv\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aless\desktop\codes\venv\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aless\desktop\codes\venv\lib\site-packages (from pandas->kagglehub[pandas-datasets]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aless\desktop\codes\venv\lib\site-packages (from requests->kagglehub[pandas-datasets]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aless\desktop\codes\venv\lib\site-packages (from requests->kagglehub[pandas-datasets]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aless\desktop\codes\venv\lib\site-packages (from requests->kagglehub[pandas-datasets]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aless\desktop\codes\venv\lib\site-packages (from requests->kagglehub[pandas-datasets]) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\aless\desktop\codes\venv\lib\site-packages (from tqdm->kagglehub[pandas-datasets]) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\aless\desktop\codes\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->kagglehub[pandas-datasets]) (1.16.0)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.3 kB ? eta -:--:--
#    ------ --------------------------------- 10.2/68.3 kB ? eta -:--:--
#    ------------------ --------------------- 30.7/68.3 kB 330.3 kB/s eta 0:00:01
#    ------------------------------------ --- 61.4/68.3 kB 544.7 kB/s eta 0:00:01
#    ---------------------------------------- 68.3/68.3 kB 414.4 kB/s eta 0:00:00
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Dados

# %%
cols = [
    'class','alcohol','malic_acid','ash','alcalinity_of_ash','magnesium','total_phenols','flavanoids',
    'nonflavanoid_phenols','proanthocyanins','color_intensity','hue','od280_od315','proline'
]
data = pd.read_csv("C:/Users/aless/Downloads/Wine.csv", header=None, names=cols)
data['class'] = data['class'].astype(str)

features = data.iloc[:,1:]
X_scaled = features.sub(features.mean()).div(features.std())
data.shape
# Out:
# (178, 14)

# %%
data.head()
# Out:
#    class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    color_intensity   hue  od280_od315  proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# 2             5.68  1.03         3.17     1185
# 3             7.80  0.86         3.45     1480
# 4             4.32  1.04         2.93      735

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 178 non-null    object
#  1   alcohol               178 non-null    float64
#  2   malic_acid            178 non-null    float64
#  3   ash                   178 non-null    float64
#  4   alcalinity_of_ash     178 non-null    float64
#  5   magnesium             178 non-null    int64
#  6   total_phenols         178 non-null    float64
#  7   flavanoids            178 non-null    float64
#  8   nonflavanoid_phenols  178 non-null    float64
#  9   proanthocyanins       178 non-null    float64
#  10  color_intensity       178 non-null    float64
#  11  hue                   178 non-null    float64
#  12  od280_od315           178 non-null    float64
#  13  proline               178 non-null    int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 19.6+ KB

# %%
data['class'].value_counts(normalize=True).to_frame().join(data['class'].value_counts())
# Out:
#        proportion  count
# class
# 2        0.398876     71
# 1        0.331461     59
# 3        0.269663     48

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.boxplot(X_scaled)
ax.set_xticklabels(X_scaled.columns, rotation=45)
ax.grid(axis='y', linestyle=':')
ax.set_title('Histograma das variáveis')
plt.show()

# %%
features.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280_od315      proline
# count       178.000000  178.000000   178.000000   178.000000
# mean          5.058090    0.957449     2.611685   746.893258
# std           2.318286    0.228572     0.709990   314.907474
# min           1.280000    0.480000     1.270000   278.000000
# 25%           3.220000    0.782500     1.937500   500.500000
# 50%           4.690000    0.965000     2.780000   673.500000
# 75%           6.200000    1.120000     3.170000   985.000000
# max          13.000000    1.710000     4.000000  1680.000000

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(
    features.corr(),
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    linewidths=.5,
    cbar_kws={"shrink": .7}
)
plt.title("Matriz de Correlação", fontsize=16)
plt.show()

# %% [markdown]
# # PCA

# %%
pca = PCA()
pca.fit(X_scaled)

P = pca.components_.T # matriz nxn cujas colunas são os componentes principais
Lambda = pca.explained_variance_ # matriz nxn cuja diagonal são os autovalores

Y = pca.transform(X_scaled) # scores
explained = pca.explained_variance_ratio_

# %%
X_scaled@P[:,:2]
# Out:
#             0         1
# 0    3.307421  1.439402
# 1    2.203250 -0.332455
# 2    2.509661  1.028251
# 3    3.746497  2.748618
# 4    1.006070  0.867384
# ..        ...       ...
# 173 -3.361043  2.210055
# 174 -2.594637  1.752286
# 175 -2.670307  2.753133
# 176 -2.380303  2.290884
# 177 -3.199732  2.761131
#
# [178 rows x 2 columns]

# %%
plt.figure(figsize=(8, 3))
plt.bar(range(1, len(explained)+1), explained)
plt.plot(range(1, len(explained)+1), np.cumsum(explained), marker='o')

plt.xlabel("Componente Principal")
plt.ylabel("Variância Explicada")
plt.title("PCA - Variância Explicada por Componente")
plt.xticks(range(1, len(explained)+1))
plt.grid(linestyle='--')
plt.show()

# %%
n_components=2
pca2 = PCA(n_components)
X_pca2 = pca2.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8,4))
plt.scatter(X_pca2[:,0], X_pca2[:,1], c=data['class'].astype(int))
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA - Componentes 1 e 2")
plt.show()

# %%
loadings = P * np.sqrt(Lambda)
loading_df = pd.DataFrame(
    loadings,
    index=features.columns,
    columns=[f"PC{i+1}" for i in range(loadings.shape[1])]
)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(
    loading_df,
    cmap="coolwarm",
    annot=True,
    fmt=".2f",
    linewidths=.5
)
plt.title("Heatmap dos Loadings do PCA")
plt.show()

# %% [markdown]
# # Dados com posto incompleto

# %%
np.linalg.matrix_rank(features)
# Out:
# np.int64(13)

# %%
#Y[:,:n_components]@P[:,:n_components].T
X_singular = pca2.inverse_transform(X_pca2) 
X_singular_scaled = (X_singular-np.mean(X_singular)) / np.std(X_singular)
np.linalg.matrix_rank(X_singular)
# Out:
# np.int64(2)

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.boxplot(X_singular_scaled)
ax.set_xticklabels(X_scaled.columns, rotation=45)
ax.grid(axis='y', linestyle=':')
ax.set_title('Histograma das variáveis')
plt.show()

# %% [markdown]
# # PCA Esparso

# %%
spca = SparsePCA(alpha=15, random_state=0)
spca.fit(X_singular_scaled)

P_spca = spca.components_.T # matriz de componentes esparsas
Y_spca = spca.transform(X_singular_scaled) # scores

# %%
pd.DataFrame(spca.components_, columns=features.columns).abs().sum().where(lambda x: x > 0).dropna()
# Out:
# total_phenols      1.0
# flavanoids         1.0
# color_intensity    1.0
# od280_od315        1.0
# proline            1.0
# dtype: float64

# %%
spca = SparsePCA(n_components=2, alpha=15, random_state=0)
spca.fit(X_singular_scaled)
Y2_spca = spca.transform(X_singular_scaled) # scores

# %%
plt.figure(figsize=(8,4))
plt.scatter(Y2_spca[:,0], Y2_spca[:,1], c=data['class'].astype(int))
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Esparso - Componentes 1 e 2")
plt.show()
