# %% [markdown]
# $ \textbf{Aluna:}$ Alessandra da Silva Dias Malizia
# $ \textbf{Data:}$ 11/06/2025

# %% [markdown]
# # Lista Prática 2

# %%
import numpy as np
import math
from tqdm import tqdm
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.stats.stattools import jarque_bera
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import breakvar_heteroskedasticity_test
from scipy.optimize import minimize

# %% [markdown]
# # Preparação dos dados

# %%
data_base = pd.read_csv('C:/Users/aless/Desktop/Codes/masters/Modelos estruturais/dados_precipitacao.csv')
data_base.dtypes
# Out:
# id_estacao             object
# estacao                object
# data_fundacao          object
# ano                     int64
# mes                     int64
# precipitacao_total    float64
# dtype: object

# %%
data_base['data'] = pd.to_datetime(data_base.apply(lambda row: '{}-{:02}-01'.format(row.ano, row.mes), axis=1))
data = data_base.pivot_table(index='data', columns='estacao', values='precipitacao_total')

# %%
estacoes = data.apply(lambda col: col.dropna().index[0]).sort_values().head(5).index
data.apply(lambda col: col.dropna().index[0]).sort_values().head(10)
# Out:
# estacao
# Manaus                         2000-05-01
# Brasilia                       2000-05-01
# Seropedica-Ecologia Agricola   2000-05-01
# Porto Alegre                   2000-09-01
# Salvador                       2000-10-01
# Morrinhos                      2001-05-01
# Goiania                        2001-05-01
# Bauru                          2001-08-01
# Campo Grande                   2001-09-01
# Tres Lagoas                    2001-09-01
# dtype: datetime64[ns]

# %%
fig, ax = plt.subplots(5, figsize=(15,10))

for i in range(5):
    ax[i].plot(data[estacoes].iloc[:,i])
    ax[i].set_title(estacoes[i])
    # ax[i].grid()


fig.suptitle('Precipitação total mensal por estação meteorológica do INMET (em mm)')
fig.tight_layout()
plt.show()

# %%
series = data[['Brasilia']]

# %%
series.to_csv('C:\\Users\\aless\\Desktop\\Codes\\masters\\Modelos estruturais\\dados_precipitacao_bsb.csv', index=True)

# %% [markdown]
# # Questão 1

# %% [markdown]
# ## a)
# - Gráfico da série temporal
# - FAC
# - FAC da 1 diferença
# - FAC da 1 diferença da diferença sazonal

# %%
fig, ax = plt.subplots(figsize=(8,3))

ax.plot(series)
ax.set_title('Time Series')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

plot_acf(series, ax=ax, title='FAC')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

plot_acf(series.diff(12), ax=ax, title='FAC da diferença sazonal')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

plot_acf(series.diff(), ax=ax, title='FAC da 1 diferença')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))

plot_acf(series.diff(12).diff(), ax=ax, title='FAC da 1 diferença da diferença sazonal')

plt.show()

# %% [markdown]
# ## b)
# - Boxplot da série original
# - Boxplot da 1 diferença

# %%
fig, ax = plt.subplots(figsize=(10,5))
plot_data = (series
    .pivot_table(columns=series.index.month, index=series.index.year, values='Brasilia')
    .dropna()
)
ax.boxplot(plot_data)
ax.set_ylabel('mm')
ax.set_xlabel('Mês')
ax.grid(axis='y', linestyle=':')
ax.set_title('Histograma da precipitação mensal em Brasilia')
plt.show()

# %% [markdown]
# ## c) Teste de sazonalidade

# %%
acorr_ljungbox(series['Brasilia'], lags=[15])
# Out:
#        lb_stat      lb_pvalue
# 15  682.041703  1.246815e-135

# %%
fig, ax = plt.subplots(figsize=(8,3))

plot_pacf(series, ax=ax, title='FACP da série original')
ax.grid(axis='both', linestyle=':')
plt.show()

# %% [markdown]
# # 1) Sazonalidade com trigonométricos

# %% [markdown]
# ## d) Estimação do modelo

# %%
def KalmanFilter(Y, T, Z, Q, H, C, D, x0, P0):
    
    n = len(Y)
    p = Y.shape[1]
    m = T.shape[0]

    # inicialização dos arrays
    x_hat = np.ones((n, m, 1))
    x_hat_minus = np.ones((n, m, 1))
    P_minus_t = np.zeros((n, m, m))
    P = np.zeros((n, m, m))
    F_t = np.zeros((n, p, p))
    v_t = np.zeros((n, p, 1))
    
    # valores inicias
    x_hat[0] = x0
    x_hat_minus[0] = x0
    P[0] = P0
    P_minus_t[0] = P0
    F_t[0] = H
    log_likelihood = -n/2 * np.log(2 * np.pi)

    # Kalman filter
    for iteration in range(1, n):
        # previsão
        x_hat_minus[iteration] = T @ x_hat[iteration - 1] + C        
        P_minus = np.array(T @ P[iteration - 1] @ T.T + Q)
        P_minus = P_minus.reshape((m, m))
        P_minus_t[iteration] = P_minus

        # inovação e variança da inovação
        eta_t = Y[iteration].reshape(p, 1) - Z[iteration] @ x_hat_minus[iteration] - D
        v_t[iteration] = eta_t
        F_t[iteration] = Z[iteration] @ P_minus_t[iteration] @ Z[iteration].T + H
        covariance_determinant = np.linalg.det(F_t[iteration])
        if abs(covariance_determinant) == 0 or str(covariance_determinant).lower() == "nan":
            return -1e10, x_hat_minus, x_hat, P, v_t
            
        # log-likelihood
        log_like = np.log(np.linalg.det(F_t[iteration])) + eta_t.T @ np.linalg.inv(F_t[iteration]) @ eta_t
        log_likelihood -= 0.5 * log_like[0][0]

        # atualização
        Kalman_gain = P_minus_t[iteration] @ Z[iteration].T @ np.linalg.inv(F_t[iteration])
        x_hat[iteration] = x_hat_minus[iteration] + Kalman_gain @ eta_t
        P[iteration] = P_minus_t[iteration] - Kalman_gain @ Z[iteration] @ P_minus_t[iteration]

    return log_likelihood, x_hat_minus, x_hat, P, v_t

# %%
def KalmanSmoother(Y, T, Z, Q, H, C, D, x0, P0):
    # Run the forward pass
    log_likelihood, x_hat_minus, x_hat, P, v_t = KalmanFilter(Y, T, Z, Q, H, C, D, x0, P0)

    n = len(Y)
    m = T.shape[0]

    # Initializing smoothed state means and covariances
    x_hat_smooth = np.zeros((n, m, 1))
    P_smooth = np.zeros((n, m, m))
    x_hat_smooth[-1] = x_hat[-1]
    P_smooth[-1] = P[-1]
    
    # Kalman smoother iterations (backward)
    for k in range(n - 2, -1, -1):
        if m == 1:
            inverse = np.array(1 / (T@P[k]@T.T + Q)).reshape(m,m)
        else:
            inverse = np.linalg.inv(T@P[k]@T.T + Q)
        J = P[k]@T.T@inverse
        x_hat_smooth[k] = x_hat[k] + J@(x_hat_smooth[k + 1] - T@x_hat[k])
        P_smooth[k] = P[k] + J@(P_smooth[k + 1] - T@P[k]@T.T + Q - P[k])@J.T

    return log_likelihood, x_hat_smooth, x_hat_minus, x_hat, P_smooth, v_t

# %%
def callback_function(xk):
    print("Iteration:", callback_function.iteration)
    print("Loss function value:", neg_log_likelihood(xk, Y, Z_t, T, C, D, x0, P0))
    print("Optimized parameters:", xk)
    print("-" * 85)
    callback_function.iteration += 1
    parameters.append(xk)

# %%
def neg_log_likelihood(theta, Y, Z, T, C, D, x0, P0):
    sigma_eps, sigma_eta, sigma_zeta, sigma_omega = theta

    m = T.shape[0]
    H = np.array([[sigma_eps**2]])
    Q = np.zeros((m, m))
    Q[0, 0] = sigma_eta**2 # nivel
    Q[1, 1] = sigma_zeta**2 # inclinação
    Q[2:, 2:] = (sigma_omega**2) * np.eye(m - 2) # sazonalidade

    log_like, *_ = KalmanFilter(Y, T, Z, Q, H, C, D, x0, P0)
    return -log_like

# %%
def compute_aic(log_likelihood, n_obs, P0, num_variances):
    # estados iniciais difusos
    q = np.sum(np.diag(P0) > 1e5)
    aic = (1 / n_obs) * (-2 * n_obs * log_likelihood + 2 * (q + num_variances))
    return aic

# %%
n_harm = 6
N = series.shape[0]
m = 2 + 2*n_harm - 1 # mu, beta, gamma 1 a n, gamma* 1 a n-1

Z = np.zeros((1, m))
Z[0, 0] = 1  # mu
Z[0, 2::2] = 1  # pega todas as gammas e ignora os gammas*
Z_t = np.tile(Z, (N, 1, 1)) # expande Z no tempo com Z fixo

T = np.zeros((m, m))
T[0, 0] = 1   # mu_t = mu_{t-1} + beta_{t-1}
T[0, 1] = 1
T[1, 1] = 1   # beta_t = beta_{t-1}

# blocos sazonais C_j (2x2)
for j in range(n_harm - 1):
    angle = np.pi * (j + 1) / 6
    Cj = np.array([
        [np.cos(angle), np.sin(angle)],
        [-np.sin(angle), np.cos(angle)]
    ])
    row = 2 + 2 * j
    T[row:row+2, row:row+2] = Cj
T[-1, -1] = -1 # Último harmônico

C = np.zeros((m, 1))
D = np.zeros((1, 1))

# inicialização com alta variancia para componentes não etacionários
x0 = np.zeros((m, 1))
P0 = np.eye(m) * 10 
P0[0, 0] = 1e7  # mu_t
P0[1, 1] = 1e7  # beta_t

Y = series.values

# %%
bounds_= [(1e-6, None)] * 4
initial_guess = np.array([10, 0.05, 0.05, 0.05])
parameters = [initial_guess.copy()]

callback_function.iteration = 1

result = minimize(
    neg_log_likelihood,
    x0 = initial_guess,
    args = (Y, Z_t, T, C, D, x0, P0),
    callback = callback_function,
    method = "L-BFGS-B",
    bounds = bounds_,
    tol = 1e-6,
    options = {'maxiter': 200},
)
result
# Out:
# Iteration: 1
# Loss function value: 6025.200351873066
# Optimized parameters: [10.3841082   0.05595143  0.61186007  0.78262455]
# -------------------------------------------------------------------------------------
# Iteration: 2
# Loss function value: 2376.774307841294
# Optimized parameters: [11.3419489   0.0645758   1.27531123  3.79661786]
# -------------------------------------------------------------------------------------
# Iteration: 3
# Loss function value: 2240.2154114478762
# Optimized parameters: [11.40770616  0.06568674  1.37916502  4.24648482]
# -------------------------------------------------------------------------------------
# Iteration: 4
# Loss function value: 1990.159038436067
# Optimized parameters: [11.57672575  0.06937627  1.69572454  5.64645964]
# -------------------------------------------------------------------------------------
# Iteration: 5
# Loss function value: 1893.5295953458376
# Optimized parameters: [11.69279048  0.07279858  1.93105025  6.76199002]
# -------------------------------------------------------------------------------------
# Iteration: 6
# Loss function value: 1834.7851362804874
# Optimized parameters: [11.83569712  0.07789427  2.16820607  8.07680817]
# -------------------------------------------------------------------------------------
# Iteration: 7
# Loss function value: 1808.5063276266512
# Optimized parameters: [12.00797203  0.08456337  2.31006116  9.29185061]
# -------------------------------------------------------------------------------------
# Iteration: 8
# Loss function value: 1797.2654732742553
# Optimized parameters: [12.25591996  0.09412254  2.29114943 10.36773876]
# -------------------------------------------------------------------------------------
# Iteration: 9
# Loss function value: 1792.28455607343
# Optimized parameters: [12.62742018  0.10808288  2.02208847 11.1994393 ]
# -------------------------------------------------------------------------------------
# Iteration: 10
# Loss function value: 1787.5346318306417
# Optimized parameters: [13.32030109  0.1344213   1.29946713 12.00439376]
# -------------------------------------------------------------------------------------
# Iteration: 11
# Loss function value: 1785.4285352855518
# Optimized parameters: [14.22738352  0.17346641  0.64576329 12.63876264]
# -------------------------------------------------------------------------------------
# Iteration: 12
# Loss function value: 1784.933814200179
# Optimized parameters: [13.92847595  0.17261398  0.59768994 12.29068707]
# -------------------------------------------------------------------------------------
# Iteration: 13
# Loss function value: 1784.8380131228714
# Optimized parameters: [13.74491001  0.17298242  0.66318532 12.08853829]
# -------------------------------------------------------------------------------------
# Iteration: 14
# Loss function value: 1784.7875124291788
# Optimized parameters: [13.77798619  0.18838899  0.62898352 12.00498368]
# -------------------------------------------------------------------------------------
# Iteration: 15
# Loss function value: 1784.7367948447936
# Optimized parameters: [13.9132511   0.21165254  0.6136216  11.97804596]
# -------------------------------------------------------------------------------------
# Iteration: 16
# Loss function value: 1784.1431480101342
# Optimized parameters: [15.88484691  0.53834013  0.49341704 11.70417632]
# -------------------------------------------------------------------------------------
# Iteration: 17
# Loss function value: 1782.0726705359061
# Optimized parameters: [22.42986979  1.62199539  0.25530513 10.85439177]
# -------------------------------------------------------------------------------------
# Iteration: 18
# Loss function value: 1751.6626648897318
# Optimized parameters: [54.93517891  7.05904781  0.19294421  8.20308401]
# -------------------------------------------------------------------------------------
# Iteration: 19
# Loss function value: 1751.6298459660777
# Optimized parameters: [56.05244735  7.24640134  0.19277214  8.19576874]
# -------------------------------------------------------------------------------------
# Iteration: 20
# Loss function value: 1730.645013602332
# Optimized parameters: [76.28216269  9.48266259  0.08869735  3.77097363]
# -------------------------------------------------------------------------------------
# Iteration: 21
# Loss function value: 1728.46588011626
# Optimized parameters: [7.81640226e+01 9.44996187e+00 6.70717733e-02 2.85155059e+00]
# -------------------------------------------------------------------------------------
# Iteration: 22
# Loss function value: 1726.1928479674145
# Optimized parameters: [6.94571725e+01 8.05947827e+00 1.00000000e-06 2.74506715e+00]
# -------------------------------------------------------------------------------------
# Iteration: 23
# Loss function value: 1726.1032256449216
# Optimized parameters: [7.11509333e+01 8.34330623e+00 1.00000000e-06 2.82118564e+00]
# -------------------------------------------------------------------------------------
# Iteration: 24
# Loss function value: 1726.0601087594903
# Optimized parameters: [7.12714352e+01 8.20518720e+00 4.74597744e-02 2.79749077e+00]
# -------------------------------------------------------------------------------------
# Iteration: 25
# Loss function value: 1726.0442193236863
# Optimized parameters: [7.11037656e+01 8.06404103e+00 6.72134199e-02 2.79006076e+00]
# -------------------------------------------------------------------------------------
# Iteration: 26
# Loss function value: 1726.0034329660082
# Optimized parameters: [7.05543929e+01 7.79921392e+00 5.75904674e-02 2.75041614e+00]
# -------------------------------------------------------------------------------------
# Iteration: 27
# Loss function value: 1725.9518627518444
# Optimized parameters: [7.07465414e+01 7.54035466e+00 6.24956550e-02 2.75498213e+00]
# -------------------------------------------------------------------------------------
# Iteration: 28
# Loss function value: 1725.8728511592876
# Optimized parameters: [71.45051983  6.64212244  0.07816551  2.79211222]
# -------------------------------------------------------------------------------------
# Iteration: 29
# Loss function value: 1725.8723158218945
# Optimized parameters: [71.5079471   6.71303468  0.07760317  2.78467126]
# -------------------------------------------------------------------------------------
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1725.8723158218945
#         x: [ 7.151e+01  6.713e+00  7.760e-02  2.785e+00]
#       nit: 29
#       jac: [ 1.364e-03  1.796e-03  3.781e-02 -1.160e-02]
#      nfev: 235
#      njev: 47
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>

# %%
sigma_eps = result.x[0]
H = np.array([[sigma_eps**2]])

sigma_eta, sigma_zeta, sigma_omega = result.x[1], result.x[2], result.x[3]
Q = np.zeros((m, m))
Q[0, 0] = sigma_eta**2
Q[1, 1] = sigma_zeta**2
Q[2:, 2:] = sigma_omega**2 * np.eye(m - 2)

log_likelihood, x_hat_smooth, x_hat_minus, x_hat, P, v_t = KalmanSmoother(Y, T, Z_t, Q, H, C, D, x0, P0)
print(f"Log Likelihood is {log_likelihood}")
# Out:
# Log Likelihood is -1725.8723158218945

# %%
resultados = {
    'inovacao': pd.Series(index=series.index, data=v_t.reshape(-1), name='inovacao'),
    'predicted': pd.DataFrame(
        index=series.index, 
        data={
            'tendencia':x_hat_minus[:,0,:].reshape(-1), 
            'inclinacao':x_hat_minus[:,1,:].reshape(-1),
            'sazonalidade':(Z_t[:,[0],2:] @ x_hat_minus[:,2:]).reshape(-1)
        }),
    'filtered': pd.DataFrame(
        index=series.index, 
        data={
            'tendencia':x_hat[:,0,:].reshape(-1), 
            'inclinacao':x_hat[:,1,:].reshape(-1),
            'sazonalidade':(Z_t[:,[0],2:] @ x_hat[:,2:]).reshape(-1)
        }),
    'smoothed': pd.DataFrame(
        index=series.index, 
        data={
            'tendencia':x_hat_smooth[:,0,:].reshape(-1), 
            'inclinacao':x_hat_smooth[:,1,:].reshape(-1),
            'sazonalidade':(Z_t[:,[0],2:] @ x_hat_smooth[:,2:]).reshape(-1)
        })
}

del Y, T, Z, Z_t, Q, H, C, D, x0, P0, x_hat_smooth, x_hat_minus, x_hat, P, v_t

# %%
print(f"Log Likelihood is {log_likelihood}")
# Out:
# Log Likelihood is -1725.8723158218945

# %% [markdown]
# ## e) Estimativas das variâncias [TODO]

# %%
result.x
# Out:
# array([71.5079471 ,  6.71303468,  0.07760317,  2.78467126])

# %% [markdown]
# ## f) Inovações

# %%
# inovações padronizadas
inovacoes = resultados['inovacao']
inovacoes = inovacoes.sub(inovacoes.mean()).div(inovacoes.std())

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(inovacoes)
ax.set_title('Inovações padronizadas')
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(8,6))
plot_acf(inovacoes, ax=ax[0], title='FAC das inovações')
plot_acf(inovacoes.pow(2), ax=ax[1], title='FAC do quadrado das inovações')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.hist(inovacoes)
ax.set_title('Histograma das inovações padronizadas')
plt.show()

# %%
df_diagnostics = pd.DataFrame(columns=['Teste','Resultado'])

# coeficientes de assimetria e curtose
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Assimetria', 'Coeficiente: {:.2f}'.format(inovacoes.skew())]
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Curtose', 'Coeficiente: {:.2f}'.format(inovacoes.kurtosis()+3)]

# teste de jarque-bera
jb_result = jarque_bera(inovacoes)
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Jarque-Bera', 'Estatística: {:.1f}, p-valor: {:.2f}'.format(jb_result[0], jb_result[1])]

# teste H
H_result = breakvar_heteroskedasticity_test(inovacoes, subset_length=1/3)
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Teste H', 'Estatística: {:.1f}, p-valor: {:.2f}'.format(H_result[0], H_result[1])]

df_diagnostics.set_index('Teste')
# Out:
#                                     Resultado
# Teste
# Assimetria                  Coeficiente: 0.82
# Curtose                     Coeficiente: 4.89
# Jarque-Bera  Estatística: 73.9, p-valor: 0.00
# Teste H       Estatística: 0.8, p-valor: 0.41

# %% [markdown]
# ## g) Gráfico das componentes

# %%
fig, ax = plt.subplots(2, figsize=(10,6))

var = 'tendencia'
mod = 'filtered'
ax[0].plot(resultados[mod][var])
ax[0].set_title(mod.capitalize())

mod = 'smoothed'
ax[1].plot(resultados[mod][var])
ax[1].set_title(mod.capitalize())

fig.suptitle('Componente da {}'.format(var.capitalize()), x=0.15)
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(10,6))

var = 'inclinacao'
mod = 'filtered'
ax[0].plot(resultados[mod][var])
ax[0].set_title(mod.capitalize())

mod = 'smoothed'
ax[1].plot(resultados[mod][var])
ax[1].set_title(mod.capitalize())

fig.suptitle('Componente da {}'.format(var.capitalize()), x=0.15)
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(10,6))

var = 'sazonalidade'
mod = 'filtered'
ax[0].plot(resultados[mod][var])
ax[0].set_title(mod.capitalize())

mod = 'smoothed'
ax[1].plot(resultados[mod][var])
ax[1].set_title(mod.capitalize())

fig.suptitle('Componente da {}'.format(var.capitalize()), x=0.15)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## h) Efeito sazonal por mês

# %%
sazonalidade = (
    resultados['smoothed'][['sazonalidade']]
    .pivot_table(
        index = resultados['smoothed'].index.year, 
        columns = resultados['smoothed'].index.month_name(), 
        values = 'sazonalidade'
    ))[['January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]]

# %%
fig, ax = plt.subplots(6, 2, figsize=(10,10))

for i in range(12): 
    row, col = i//2, i%2
    ax[row][col].plot(sazonalidade.iloc[:,i])
    ax[row][col].set_title('{}'.format(sazonalidade.columns[i]))

fig.suptitle('Sazonalidade suavizada')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## i) Valores faltantes [TODO]

# %% [markdown]
# ## j) Capacidade preditiva [TODO]

# %% [markdown]
# # 2) Sazonalidade com dummies
#
# $$
# \begin{align*}
# y_t &= \mu_t + \gamma_t + \varepsilon_t \\
# \mu_t &= \mu_{t-1} + \beta_{t-1} + \eta_t \\
# \beta_t &= \beta_{t-1} + \zeta_t \\
# \gamma_t &= D_t^\top S_t \\
# S_t &= S_{t-1} + \omega_t
# \end{align*}
# $$

# %%
def neg_log_likelihood(theta, Y, Z, T, C, D, x0, P0):
    sigma_eps, sigma_eta, sigma_zeta, sigma_omega = theta

    m = T.shape[0]
    H = np.array([[sigma_eps**2]])
    
    Q = np.zeros((m, m))
    Q[0, 0] = sigma_eta**2 # nivel
    Q[1, 1] = sigma_zeta**2 # inclinação
    I, i = np.eye(12), np.ones((12, 1))
    Sigma_star = sigma_omega * (I - (1/12) * i @ i.T)
    Q[2:, 2:] = Sigma_star # sazonalidade

    log_like, *_ = KalmanFilter(Y, T, Z, Q, H, C, D, x0, P0)
    return -log_like

# %%
n = series.shape[0]
m = 14 # mu, beta, D1 a D12

Z_t = np.zeros((n, 1, m))
for t in range(n):
    month = series.index[t].month
    Z_t[t, 0, 0] = 1  # mu_t
    Z_t[t, 0, 2 + (month - 1)] = 1  # Dummies sazonais

T = np.eye(14)
T[0, 1] = 1  # mu_t = mu_{t-1} + beta_{t-1}

C = np.zeros((m, 1))
D = np.zeros((1, 1))

x0 = np.zeros((m, 1))
P0 = np.eye(m) * 10
P0[0, 0] = 1e7  # mu_t
P0[1, 1] = 1e7  # beta_t

Y = series.values

# %%
bounds_= [(1e-6, None)] * 4
initial_guess = np.array([10, 0.05, 0.05, 0.05])
parameters = [initial_guess.copy()]

callback_function.iteration = 1

result = minimize(
    neg_log_likelihood,
    x0 = initial_guess,
    args = (Y, Z_t, T, C, D, x0, P0),
    callback = callback_function,
    method = "L-BFGS-B",
    bounds = bounds_,
    tol = 1e-6,
    options = {'maxiter': 200},
)
result
# Out:
# Iteration: 1
# Loss function value: 7875.61330132072
# Optimized parameters: [10.10212667  0.05164473  0.19773088  1.03373931]
# -------------------------------------------------------------------------------------
# Iteration: 2
# Loss function value: 7016.109079037944
# Optimized parameters: [10.54229986  0.05577198  0.50177533  1.40086186]
# -------------------------------------------------------------------------------------
# Iteration: 3
# Loss function value: 5293.002129877646
# Optimized parameters: [12.3083943   0.06346905  0.70231818  2.51398319]
# -------------------------------------------------------------------------------------
# Iteration: 4
# Loss function value: 4138.9429264673445
# Optimized parameters: [14.56512559  0.07210299  0.89840199  3.61982054]
# -------------------------------------------------------------------------------------
# Iteration: 5
# Loss function value: 3267.6937505153874
# Optimized parameters: [17.70312174  0.0831334   1.08137831  4.95215192]
# -------------------------------------------------------------------------------------
# Iteration: 6
# Loss function value: 2693.1278393398316
# Optimized parameters: [21.55964228  0.09683918  1.18704678  6.43411574]
# -------------------------------------------------------------------------------------
# Iteration: 7
# Loss function value: 2309.007084835116
# Optimized parameters: [26.35304155  0.1169709   1.11832365  8.1582429 ]
# -------------------------------------------------------------------------------------
# Iteration: 8
# Loss function value: 2060.381210396853
# Optimized parameters: [32.15807248  0.15248625  0.69225985 10.16657535]
# -------------------------------------------------------------------------------------
# Iteration: 9
# Loss function value: 1905.776935529199
# Optimized parameters: [38.91005179  0.23756996  0.4011039  12.4221501 ]
# -------------------------------------------------------------------------------------
# Iteration: 10
# Loss function value: 1822.876528911775
# Optimized parameters: [46.79556012  0.48628873  2.60471464 14.91711614]
# -------------------------------------------------------------------------------------
# Iteration: 11
# Loss function value: 1778.7669988339899
# Optimized parameters: [53.60788977  0.70350535  1.89864797 17.27152855]
# -------------------------------------------------------------------------------------
# Iteration: 12
# Loss function value: 1773.8105929925339
# Optimized parameters: [6.28073704e+01 1.15029537e+00 1.00000000e-06 2.12816342e+01]
# -------------------------------------------------------------------------------------
# Iteration: 13
# Loss function value: 1771.7542519096633
# Optimized parameters: [1.20863176e+02 5.67602915e+00 1.00000000e-06 4.65691514e+01]
# -------------------------------------------------------------------------------------
# Iteration: 14
# Loss function value: 1752.7811157579663
# Optimized parameters: [1.05811256e+02 5.11264078e+00 1.00000000e-06 4.01618878e+01]
# -------------------------------------------------------------------------------------
# Iteration: 15
# Loss function value: 1728.6446437370507
# Optimized parameters: [7.07743012e+01 5.73950568e+00 1.00000000e-06 2.68632059e+01]
# -------------------------------------------------------------------------------------
# Iteration: 16
# Loss function value: 1727.0056878762578
# Optimized parameters: [7.73038980e+01 7.84425506e+00 1.00000000e-06 3.57488262e+01]
# -------------------------------------------------------------------------------------
# Iteration: 17
# Loss function value: 1726.1783351299164
# Optimized parameters: [7.37369429e+01 8.07841884e+00 1.00000000e-06 3.57802973e+01]
# -------------------------------------------------------------------------------------
# Iteration: 18
# Loss function value: 1726.1562540619382
# Optimized parameters: [7.37200276e+01 8.07751630e+00 4.46596389e-02 3.58042930e+01]
# -------------------------------------------------------------------------------------
# Iteration: 19
# Loss function value: 1726.0536407717666
# Optimized parameters: [7.20774739e+01 8.22774267e+00 1.00000000e-06 3.63425583e+01]
# -------------------------------------------------------------------------------------
# Iteration: 20
# Loss function value: 1725.8511276045972
# Optimized parameters: [7.18822533e+01 8.25276279e+00 1.00000000e-06 3.86011712e+01]
# -------------------------------------------------------------------------------------
# Iteration: 21
# Loss function value: 1725.4797983199192
# Optimized parameters: [7.17279327e+01 8.08858873e+00 1.00000000e-06 4.55737077e+01]
# -------------------------------------------------------------------------------------
# Iteration: 22
# Loss function value: 1725.436469453833
# Optimized parameters: [7.16566388e+01 8.02146636e+00 5.23364610e-02 4.61298072e+01]
# -------------------------------------------------------------------------------------
# Iteration: 23
# Loss function value: 1725.3634241179725
# Optimized parameters: [7.08364527e+01 7.53808734e+00 4.95740281e-02 5.48654337e+01]
# -------------------------------------------------------------------------------------
# Iteration: 24
# Loss function value: 1725.353057036821
# Optimized parameters: [7.08920641e+01 7.49729732e+00 6.38134377e-02 5.47718417e+01]
# -------------------------------------------------------------------------------------
# Iteration: 25
# Loss function value: 1725.3075954880815
# Optimized parameters: [7.16094162e+01 7.48727294e+00 6.21865253e-02 5.02187844e+01]
# -------------------------------------------------------------------------------------
# Iteration: 26
# Loss function value: 1725.2816490829614
# Optimized parameters: [7.15309406e+01 7.28193536e+00 6.80607633e-02 5.03528388e+01]
# -------------------------------------------------------------------------------------
# Iteration: 27
# Loss function value: 1725.2494238354184
# Optimized parameters: [71.45066182  6.66230836  0.07770483 49.91019563]
# -------------------------------------------------------------------------------------
# Iteration: 28
# Loss function value: 1725.2491895103678
# Optimized parameters: [71.46099853  6.69827669  0.07758889 50.06961889]
# -------------------------------------------------------------------------------------
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 1725.2491895103678
#         x: [ 7.146e+01  6.698e+00  7.759e-02  5.007e+01]
#       nit: 28
#       jac: [ 1.819e-04  4.093e-04  1.426e-02 -4.547e-05]
#      nfev: 205
#      njev: 41
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>

# %%
sigma_eps = result.x[0]
H = np.array([[sigma_eps**2]])

sigma_eta, sigma_zeta, sigma_omega = result.x[1], result.x[2], result.x[3]
Q = np.zeros((m, m))
Q[0, 0] = sigma_eta**2 # nivel
Q[1, 1] = sigma_zeta**2 # inclinação
I, i = np.eye(12), np.ones((12, 1))
Sigma_star = sigma_omega * (I - (1/12) * i @ i.T)
Q[2:, 2:] = Sigma_star # sazonalidade

log_likelihood, x_hat_smooth, x_hat_minus, x_hat, P, v_t = KalmanSmoother(Y, T, Z_t, Q, H, C, D, x0, P0)
print(f"Log Likelihood is {log_likelihood}")
# Out:
# Log Likelihood is -1725.2491895103678

# %%
resultados = {
    'inovacao': pd.Series(index=series.index, data=v_t.reshape(-1), name='inovacao'),
    'predicted': pd.DataFrame(
        index=series.index, 
        data={
            'tendencia':x_hat_minus[:,0,:].reshape(-1), 
            'inclinacao':x_hat_minus[:,1,:].reshape(-1),
            'sazonalidade':(Z_t[:,[0],2:] @ x_hat_minus[:,2:]).reshape(-1)
        }),
    'filtered': pd.DataFrame(
        index=series.index, 
        data={
            'tendencia':x_hat[:,0,:].reshape(-1), 
            'inclinacao':x_hat[:,1,:].reshape(-1),
            'sazonalidade':(Z_t[:,[0],2:] @ x_hat[:,2:]).reshape(-1)
        }),
    'smoothed': pd.DataFrame(
        index=series.index, 
        data={
            'tendencia':x_hat_smooth[:,0,:].reshape(-1), 
            'inclinacao':x_hat_smooth[:,1,:].reshape(-1),
            'sazonalidade':(Z_t[:,[0],2:] @ x_hat_smooth[:,2:]).reshape(-1)
        })
}
del Y, T, Z_t, Q, H, C, D, x0, P0, x_hat_smooth, x_hat_minus, x_hat, P, v_t

# %% [markdown]
# ## e) Estimativas das variâncias [TODO]

# %% [markdown]
# ## f) Inovações

# %%
# inovações padronizadas
inovacoes = resultados['inovacao']
inovacoes = inovacoes.sub(inovacoes.mean()).div(inovacoes.std())

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(inovacoes)
ax.set_title('Inovações padronizadas')
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(8,6))
plot_acf(inovacoes, ax=ax[0], title='FAC das inovações')
plot_acf(inovacoes.pow(2), ax=ax[1], title='FAC do quadrado das inovações')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.hist(inovacoes)
ax.set_title('Histograma das inovações padronizadas')
plt.show()

# %%
df_diagnostics = pd.DataFrame(columns=['Teste','Resultado'])

# coeficientes de assimetria e curtose
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Assimetria', 'Coeficiente: {:.2f}'.format(inovacoes.skew())]
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Curtose', 'Coeficiente: {:.2f}'.format(inovacoes.kurtosis()+3)]

# teste de jarque-bera
jb_result = jarque_bera(inovacoes)
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Jarque-Bera', 'Estatística: {:.1f}, p-valor: {:.2f}'.format(jb_result[0], jb_result[1])]

# teste H
H_result = breakvar_heteroskedasticity_test(inovacoes, subset_length=1/3)
df_diagnostics.loc[df_diagnostics.shape[0]] = ['Teste H', 'Estatística: {:.1f}, p-valor: {:.2f}'.format(H_result[0], H_result[1])]

df_diagnostics.set_index('Teste')
# Out:
#                                     Resultado
# Teste
# Assimetria                  Coeficiente: 0.82
# Curtose                     Coeficiente: 4.93
# Jarque-Bera  Estatística: 75.7, p-valor: 0.00
# Teste H       Estatística: 0.9, p-valor: 0.44

# %% [markdown]
# ## g) Gráfico das componentes

# %%
fig, ax = plt.subplots(2, figsize=(10,6))

var = 'tendencia'
mod = 'filtered'
ax[0].plot(resultados[mod][var])
ax[0].set_title(mod.capitalize())

mod = 'smoothed'
ax[1].plot(resultados[mod][var])
ax[1].set_title(mod.capitalize())

fig.suptitle('Componente da {}'.format(var.capitalize()), x=0.15)
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(10,6))

var = 'inclinacao'
mod = 'filtered'
ax[0].plot(resultados[mod][var])
ax[0].set_title(mod.capitalize())

mod = 'smoothed'
ax[1].plot(resultados[mod][var])
ax[1].set_title(mod.capitalize())

fig.suptitle('Componente da {}'.format(var.capitalize()), x=0.15)
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(10,6))

var = 'sazonalidade'
mod = 'filtered'
ax[0].plot(resultados[mod][var])
ax[0].set_title(mod.capitalize())

mod = 'smoothed'
ax[1].plot(resultados[mod][var])
ax[1].set_title(mod.capitalize())

fig.suptitle('Componente da {}'.format(var.capitalize()), x=0.15)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## h) Efeito sazonal por mês

# %%
sazonalidade = (
    resultados['smoothed'][['sazonalidade']]
    .pivot_table(
        index = resultados['smoothed'].index.year, 
        columns = resultados['smoothed'].index.month_name(), 
        values = 'sazonalidade'
    ))[['January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]]

# %%
fig, ax = plt.subplots(6, 2, figsize=(10,10))

for i in range(12): 
    row, col = i//2, i%2
    ax[row][col].plot(sazonalidade.iloc[:,i])
    ax[row][col].set_title('{}'.format(sazonalidade.columns[i]))

fig.suptitle('Sazonalidade suavizada')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## i) Valores faltantes [TODO]

# %% [markdown]
# ## j) Capacidade preditiva [TODO]
