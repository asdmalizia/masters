# %% [markdown]
# $ \textbf{Aluna:}$ Alessandra da Silva Dias Malizia
# $ \textbf{Data:}$ 12/07/2025

# %% [markdown]
# # Trabalho de Simulação

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import scipy.stats as stats
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.optimize import minimize
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args

# %%
rng = np.random.default_rng(seed=4)

# %% [markdown]
# # Modelos

# %% [markdown]
# ## AR
# $ y_t = \phi y_{t-1} + \varepsilon_t,   \varepsilon_t \sim N(0, \sigma^2)
# $ e $p(y_1) \sim N(a_1, P_1)
# $

# %%
T = 100 # número de observações
ϕ, σ = 0.8, 1.5 # parâmetros reais

ϵt = rng.normal(0, σ, size=T)
y_true = np.zeros(T)

for t in range(1, T):
    y_true[t] = ϕ*y_true[t-1] + ϵt[t]

# %%
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(np.arange(len(y_true)), y_true)
ax.set_title('Série simulada')
plt.show()

# %% [markdown]
# ### Funções

# %%
def run_model(ϕ, σ, T, N):
    a1, P1 = 0, σ**2/(1 - ϕ**2)
    
    ϵt = rng.normal(0, σ, size=(N,T))
    y1 = rng.normal(loc=a1, scale=np.sqrt(P1), size=N)
    
    yt = np.zeros((N,T))
    yt[:,0] = y1
    
    for t in range(1, T):
        yt[:,t] = ϕ*yt[:,t-1] + ϵt[:,t]
            
    yt_hat = np.mean(yt, axis=0) # média da densidade simulada
    Ft = np.mean(np.power(yt - yt_hat, 2), axis=0) # variância da densidade estimada
    vt = y_true - yt_hat # inovações
    
    return yt_hat, vt, Ft

# %%
def neg_log_likelihood(theta, y_true, N=1000):
    # ϕ, σ = theta
    ϕ, log_σ = theta
    σ = np.exp(log_σ)
    T = len(y_true)
    
    yt_hat, vt, Ft = run_model(ϕ, σ, T, N)    
    log_likelihood = (
        -T/2 * np.log(2 * np.pi)
        -0.5 * np.sum(np.log(Ft) + np.power(vt, 2)/Ft)
    )
    return -log_likelihood

# %%
neg_log_likelihood((0.8, np.log(1.5)), y_true)
# Out:
# 217.93877196604257

# %% [markdown]
# ### Otimização BFGS

# %%
def callback_function(xk):
    print("Iteration:", callback_function.iteration)
    print("Loss function value:", neg_log_likelihood(xk, y_true))
    print("Optimized parameters:", xk)
    print("-" * 85)
    callback_function.iteration += 1
    parameters.append(xk)

# %%
bounds_= [(-0.999, 0.999),(1e-6, None)]
initial_guess = np.array([0.2, np.log(10)])
parameters = [initial_guess.copy()]

callback_function.iteration = 1
result = minimize(
    neg_log_likelihood,
    x0 = initial_guess,
    args = (y_true, 10000),
    callback = callback_function,
    method = "L-BFGS-B",
    bounds = bounds_,
    tol = 1e-6,
    options = {'maxiter': 200},
)
result
# Out:
# Iteration: 1
# Loss function value: 326.02745984658793
# Optimized parameters: [0.2        2.30258516]
# -------------------------------------------------------------------------------------
# Iteration: 2
# Loss function value: 326.10784018597786
# Optimized parameters: [0.2        2.30258516]
# -------------------------------------------------------------------------------------
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 326.28044470857964
#         x: [ 2.000e-01  2.303e+00]
#       nit: 2
#       jac: [-1.269e+06 -5.787e+06]
#      nfev: 69
#      njev: 23
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %%
ϕ_hat, log_σ_hat = result.x
σ_hat = np.exp(log_σ_hat)
ϕ_hat, σ_hat
# Out:
# (0.19999999999999274, 10.000000694641974)

# %% [markdown]
# ### Otimização por Nelder-Mead

# %%
bounds_ = [(-0.999, 0.999), (np.log(1e-6), np.log(100))]
initial_guess = np.array([0.7, np.log(10)])

callback_function.iteration = 1
result = minimize(
    neg_log_likelihood,
    x0=initial_guess,
    args=(y_true, 10000),
    callback = callback_function,
    method="Nelder-Mead", 
    bounds=bounds_,
    tol = 1e-6,
    options={"maxiter": 200},
)
# Out:
# Iteration: 1
# Loss function value: 342.7339545553189
# Optimized parameters: [0.7525     2.07232658]
# -------------------------------------------------------------------------------------
# Iteration: 2
# Loss function value: 325.354975844714
# Optimized parameters: [0.70875    1.95719733]
# -------------------------------------------------------------------------------------
# Iteration: 3
# Loss function value: 290.3540937593372
# Optimized parameters: [0.791875   1.43911568]
# -------------------------------------------------------------------------------------
# Iteration: 4
# Loss function value: 242.3345682164885
# Optimized parameters: [0.7459375  0.94981635]
# -------------------------------------------------------------------------------------
# Iteration: 5
# Loss function value: 222.03348568112364
# Optimized parameters: [0.8290625 0.4317347]
# -------------------------------------------------------------------------------------
# Iteration: 6
# Loss function value: 222.13188904820993
# Optimized parameters: [0.8290625 0.4317347]
# -------------------------------------------------------------------------------------
# Iteration: 7
# Loss function value: 221.0703740784973
# Optimized parameters: [0.8290625 0.4317347]
# -------------------------------------------------------------------------------------
# Iteration: 8
# Loss function value: 216.11595938609096
# Optimized parameters: [0.79283203 0.22126404]
# -------------------------------------------------------------------------------------
# Iteration: 9
# Loss function value: 215.92676723401428
# Optimized parameters: [0.84587891 0.08454805]
# -------------------------------------------------------------------------------------
# Iteration: 10
# Loss function value: 216.2788890753925
# Optimized parameters: [0.84587891 0.08454805]
# -------------------------------------------------------------------------------------
# Iteration: 11
# Loss function value: 216.7910318114619
# Optimized parameters: [0.84587891 0.08454805]
# -------------------------------------------------------------------------------------
# Iteration: 12
# Loss function value: 215.28057944398432
# Optimized parameters: [0.84587891 0.08454805]
# -------------------------------------------------------------------------------------
# Iteration: 13
# Loss function value: 215.84360215070598
# Optimized parameters: [0.84587891 0.08454805]
# -------------------------------------------------------------------------------------
# Iteration: 14
# Loss function value: 216.08864810899104
# Optimized parameters: [0.82945343 0.13162849]
# -------------------------------------------------------------------------------------
# Iteration: 15
# Loss function value: 215.88076149495146
# Optimized parameters: [0.82945343 0.13162849]
# -------------------------------------------------------------------------------------
# Iteration: 16
# Loss function value: 216.40436715487579
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 17
# Loss function value: 216.1412399026882
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 18
# Loss function value: 215.15595458153098
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 19
# Loss function value: 216.47664948198556
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 20
# Loss function value: 214.5920014989084
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 21
# Loss function value: 215.01578161939315
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 22
# Loss function value: 216.7453308483694
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 23
# Loss function value: 216.3056013568151
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 24
# Loss function value: 215.61706984435588
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 25
# Loss function value: 215.38113242934799
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 26
# Loss function value: 215.85278703894562
# Optimized parameters: [0.83578094 0.1058256 ]
# -------------------------------------------------------------------------------------
# Iteration: 27
# Loss function value: 216.487245365791
# Optimized parameters: [0.83591676 0.10536893]
# -------------------------------------------------------------------------------------
# Iteration: 28
# Loss function value: 215.9655133019044
# Optimized parameters: [0.83591676 0.10536893]
# -------------------------------------------------------------------------------------
# Iteration: 29
# Loss function value: 214.15998519051166
# Optimized parameters: [0.83591676 0.10536893]
# -------------------------------------------------------------------------------------
# Iteration: 30
# Loss function value: 214.83539909524575
# Optimized parameters: [0.83591676 0.10536893]
# -------------------------------------------------------------------------------------
# Iteration: 31
# Loss function value: 215.4178778188615
# Optimized parameters: [0.83591676 0.10536893]
# -------------------------------------------------------------------------------------
# Iteration: 32
# Loss function value: 216.1276441455303
# Optimized parameters: [0.83591676 0.10536893]
# -------------------------------------------------------------------------------------
# Iteration: 33
# Loss function value: 214.35613634145534
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 34
# Loss function value: 215.74725545920074
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 35
# Loss function value: 215.9064762181858
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 36
# Loss function value: 214.77212782879366
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 37
# Loss function value: 214.69489945388256
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 38
# Loss function value: 214.52604942239697
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 39
# Loss function value: 216.053095343252
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 40
# Loss function value: 216.40890952938256
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 41
# Loss function value: 214.53518407124244
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 42
# Loss function value: 215.19665358923106
# Optimized parameters: [0.83588231 0.10551307]
# -------------------------------------------------------------------------------------
# Iteration: 43
# Loss function value: 216.4724061319564
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration:
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 182
# Loss function value: 214.83937831382025
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 183
# Loss function value: 214.5432535801364
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 184
# Loss function value: 214.6379869400867
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 185
# Loss function value: 214.8302791054146
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 186
# Loss function value: 215.85419192655317
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 187
# Loss function value: 215.15335135435285
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 188
# Loss function value: 216.00554460035136
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 189
# Loss function value: 214.45513635509195
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 190
# Loss function value: 213.7506173960074
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 191
# Loss function value: 214.6943050430906
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 192
# Loss function value: 216.358725286588
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 193
# Loss function value: 215.13401019597046
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 194
# Loss function value: 214.58955790683396
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 195
# Loss function value: 215.6403056738288
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 196
# Loss function value: 214.85888362420502
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 197
# Loss function value: 214.64738881297012
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 198
# Loss function value: 216.3683358647642
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------
# Iteration: 199
# Loss function value: 214.93866955505902
# Optimized parameters: [0.83588224 0.10551309]
# -------------------------------------------------------------------------------------

# %%
ϕ_hat, log_σ_hat = result.x
σ_hat = np.exp(log_σ_hat)
ϕ_hat, σ_hat
# Out:
# (0.835882243480411, 1.1112806505196284)

# %%
yt_hat, vt, _ = run_model(ϕ_hat, σ_hat, T=len(y_true), N=1000)
neg_log_likelihood((ϕ_hat, log_σ_hat), y_true)
# Out:
# 215.37646519600827

# %% [markdown]
# ### Resultados

# %%
fig, ax = plt.subplots(1,2, figsize=(10,3))

ϕ_grid = np.linspace(0.1, 0.9, 50)
losses = [neg_log_likelihood([phi, np.log(σ)], y_true, N=1000) for phi in ϕ_grid]
ax[0].plot(ϕ_grid, losses)
ax[0].set_xlabel("ϕ")
ax[0].set_ylabel("Negative Log-Likelihood")
ax[0].set_title("Curva de verossimilhança simulada para σ = {}".format(σ))
ax[0].grid(axis='both', linestyle=':')

sigma_grid = np.linspace(1, 4, 50)
losses = [neg_log_likelihood([ϕ, np.log(sigma)], y_true, N=1000) for sigma in sigma_grid]
ax[1].plot(sigma_grid, losses)
ax[1].set_xlabel("log(σ)")
ax[1].set_ylabel("Negative Log-Likelihood")
ax[1].set_title("Curva de verossimilhança simulada para ϕ = {}".format(ϕ))

plt.show()

# %%
fig, ax = plt.subplots(2, 1, figsize=(10,6))
ax[0].plot(np.arange(T), y_true, label='Série real (eixo esquerdo)', color='black')
ax2 = ax[0].twinx()
ax2.plot(np.arange(T), yt_hat, label='Série estimada (eixo direito)')
ax[0].set_title('Estimação')

ax[1].plot(np.arange(T), vt, color='C1')
ax[1].set_title('Inovações')
fig.legend(loc='lower center', ncol=2)
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(8,6))
plot_acf(vt, ax=ax[0], title='FAC das inovações')
plot_acf(vt**2, ax=ax[1], title='FAC do quadrado das inovações')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Nível local
#
# $ y_t = \alpha_t + \varepsilon_t,   \varepsilon_t \sim N(0, \sigma_\varepsilon^2)
# $
# $
# \alpha_{t+1} = \omega + \phi \alpha_{t} + \eta_t ,   \eta_t \sim N(0, \sigma_\eta^2)
# $ e $p(\alpha_1) \sim N(a_1, P_1)
# $

# %%
def particle_kalman_filter_ar1(ω, ϕ, σ_epsilon, σ_eta, y_true, T, N):
    a1 = ω / (1 - ϕ)
    P1 = σ_eta**2 / (1 - ϕ**2)
    
    α_filtered, α_pred = np.zeros(T), np.zeros(T)
    P_filtered, P_pred = np.zeros(T), np.zeros(T)
    α_pred[0] = a1
    P_pred[0] = P1
    
    yi_t = np.zeros(N)
    y_hat = np.zeros(T)
    K_t = np.zeros(T)
    
    for t in range(T):
        # Previsão
        ε_t = rng.normal(0, σ_epsilon, size=N)
        αi_minus = rng.normal(loc=α_pred[t], scale=np.sqrt(P_pred[t]), size=N)
        
        yi_t = αi_minus + ε_t
        y_hat[t] = np.mean(yi_t)
        vt[t] = y_true[t] - y_hat[t]
    
        # Estatísticas para atualização
        F_t = np.mean((yi_t - y_hat[t])**2)
        M_t = np.mean((αi_minus - α_pred[t-1]) * (yi_t - y_hat[t]))  # covariância
    
        # Atualização
        K_t[t] = M_t / F_t
        α_filtered[t] = α_pred[t] + K_t[t] * (y_true[t] - y_hat[t])
        P_filtered[t] = P_pred[t] - K_t[t]**2 * F_t
    
        if t<T-1:
            αi = rng.normal(loc=α_filtered[t], scale=np.sqrt(P_filtered[t]), size=N)
            η_t = rng.normal(0, σ_eta, size=N)
            αi = ω + ϕ * αi + η_t
            α_pred[t+1] = np.mean(αi)
            P_pred[t+1] = np.mean((αi - α_pred[t])**2)
    
    return y_hat, α_filtered, P_filtered, vt

# %%
def neg_log_likelihood(theta, y_true, N=1000):
    
    ω, ϕ, log_σ_epsilon, log_σ_eta = theta
    σ_epsilon = np.exp(log_σ_epsilon)
    σ_eta = np.exp(log_σ_eta)
    T = len(y_true)

    y_hat, vt, Ft, _ = particle_kalman_filter_ar1(ω, ϕ, σ_epsilon, σ_eta, y_true, T, N)
    
    Ft = np.maximum(Ft, 1e-6)
    log_likelihood = (
        -T/2 * np.log(2 * np.pi)
        -0.5 * np.sum(np.log(Ft) + (vt**2) / Ft)
    )
    return -log_likelihood

# %%
ω = 0.0
ϕ = 0.8
σ_epsilon = 1
σ_eta = 1
T = 100
N = 1000

# Executar o filtro
y_hat, α_hat, P_hat, vt = particle_kalman_filter_ar1(ω, ϕ, σ_epsilon, σ_eta, y_true, T, N)

# %%
neg_log_likelihood((ω, ϕ, np.log(σ_epsilon), np.log(σ_eta)), y_true)
# Out:
# 312.71386050934063

# %%
fig, ax = plt.subplots(2, 1, figsize=(10,6))
ax[0].plot(np.arange(T), y_true, label='Série real (eixo esquerdo)', color='black')
ax[0].plot(np.arange(T), y_hat, label='Série estimada (eixo direito)')
ax[0].set_title('Estimação')

ax[1].plot(np.arange(T), vt, color='C1')
ax[1].set_title('Inovações')
fig.legend(loc='lower center', ncol=2)
plt.show()

# %%
fig, ax = plt.subplots(2, figsize=(8,6))
plot_acf(vt, ax=ax[0], title='FAC das inovações')
plot_acf(vt**2, ax=ax[1], title='FAC do quadrado das inovações')
fig.tight_layout()
plt.show()
